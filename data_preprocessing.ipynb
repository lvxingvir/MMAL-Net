# %% [markdown]
# # Mura Data Preprocessing

# %%
import pandas as pd
import glob2
import os
import cv2
import sys
from matplotlib import pylab as plt
import numpy as np
from tqdm import tqdm
import shutil
import json
# import imgaug as ia
# from imgaug import augmenters as iaa

# %%
train_df = pd.read_csv(r'E:\Xing\Data\MURA-v1.1\MURA-v1.1\train_image_paths.csv', header=None, names=['FilePath'])
valid_df=pd.read_csv(r'E:\Xing\Data\MURA-v1.1\MURA-v1.1\valid_image_paths.csv', header=None, names=['FilePath'])
train_labels_df=pd.read_csv(r'E:\Xing\Data\MURA-v1.1\MURA-v1.1\train_labeled_studies.csv', names=['FilePath', 'Labels'])
valid_labels_df=pd.read_csv(r'E:\Xing\Data\MURA-v1.1\MURA-v1.1\valid_labeled_studies.csv', names=['FilePath', 'Labels'])

# %%
train_df = pd.read_csv(r'E:\Xing\Data\MURA-v1.1\MURA-v1.1\train.csv', header=0,index_col=0)
valid_df=pd.read_csv(r'E:\Xing\Data\MURA-v1.1\MURA-v1.1\valid.csv', header=0,index_col=0)

# %%
train_df.head()
# Out:
#                                             FilePath  Label
# 0  MURA-v1.1/train/XR_SHOULDER/patient00001/study...      1
# 1  MURA-v1.1/train/XR_SHOULDER/patient00001/study...      1
# 2  MURA-v1.1/train/XR_SHOULDER/patient00001/study...      1
# 3  MURA-v1.1/train/XR_SHOULDER/patient00002/study...      1
# 4  MURA-v1.1/train/XR_SHOULDER/patient00002/study...      1

# %%
train_df['BodyPart'] = train_df.apply(lambda x: x.FilePath.split('/')[2][3:],axis=1)
valid_df['BodyPart'] = valid_df.apply(lambda x: x.FilePath.split('/')[2][3:],axis=1)

# %%
train_df.head()
# Out:
#                                             FilePath  Label  BodyPart
# 0  MURA-v1.1/train/XR_SHOULDER/patient00001/study...      1  SHOULDER
# 1  MURA-v1.1/train/XR_SHOULDER/patient00001/study...      1  SHOULDER
# 2  MURA-v1.1/train/XR_SHOULDER/patient00001/study...      1  SHOULDER
# 3  MURA-v1.1/train/XR_SHOULDER/patient00002/study...      1  SHOULDER
# 4  MURA-v1.1/train/XR_SHOULDER/patient00002/study...      1  SHOULDER

# %%
train_df[train_df['BodyPart']=='SHOULDER'].Label.hist()

# %%
train_df.to_csv('train.csv')
valid_df.to_csv('valid.csv')

# %%
train_df.to_csv('train.csv')
valid_df.to_csv('valid.csv')

# %%
train_df.BodyPart.hist()
valid_df.BodyPart.hist()

# %%
import os
base_path = r'E:\Xing\Data\MURA-v1.1'
train_df['window_path'] = train_df.apply(lambda x:os.path.join(base_path,x['FilePath'].replace('/','\\')),axis=1)
valid_df['window_path'] = train_df.apply(lambda x:os.path.join(base_path,x['FilePath'].replace('/','\\')),axis=1)

# %%
w, h = 10, 10
fig = plt.figure(figsize=(15, 15))
columns, rows = 3, 2
end, start = train_df.loc[0:].shape
ax = []
import random
for i in range(columns*rows):
    # img = np.array(Image.open(train_img_path.values[k][0]))
    k = random.randint(start, end)
    title = (train_df.iloc[k,1]).split('\\')
    title = title[-4]+'-'+title[-3]+'-'+title[-2]
    print(title)
    img = cv2.imread((train_df.iloc[k,1]))
    k += 1
    # create subplot and append to ax
    ax.append( fig.add_subplot(rows, columns, i+1) )
    ax[-1].set_title(title)  # set title
    plt.xticks([])
    plt.yticks([])
    plt.imshow(img, cmap="gray")
plt.tight_layout(True)
plt.show()  # finally, render the plot
# Out:
# XR_FOREARM-patient09534-study1_negative
# XR_WRIST-patient06738-study1_positive
# XR_FINGER-patient04626-study1_negative
# XR_ELBOW-patient05396-study1_positive
# XR_HAND-patient10081-study1_positive
# XR_WRIST-patient04672-study1_negative

# %%
train_df['Label'] = train_df.apply(lambda x:1 if 'positive' in x.FilePath else 0, axis=1)
valid_df['Label'] = valid_df.apply(lambda x:1 if 'positive' in x.FilePath else 0, axis=1)

# %%
key = train_df.loc[100]['FilePath'].split('/')
key[2].split('_')[1]
# Out:
# 'SHOULDER'

# %%
train_df['BodyPart'] = train_df.apply(lambda x: x.FilePath.split('/')[2][3:],axis=1)
valid_df['BodyPart'] = valid_df.apply(lambda x: x.FilePath.split('/')[2][3:],axis=1)

# %%
keys = set(valid_df['BodyPart'])
keys
# Out:
# {'ELBOW', 'FINGER', 'FOREARM', 'HAND', 'HUMERUS', 'SHOULDER', 'WRIST'}

# %%
bp_dict={}
for i,key in enumerate(keys):
    bp_dict[key]=i

# %%
bp_dict
# Out:
# {'HUMERUS': 0,
#  'WRIST': 1,
#  'ELBOW': 2,
#  'SHOULDER': 3,
#  'FOREARM': 4,
#  'FINGER': 5,
#  'HAND': 6}

# %%
train_df['Bp_label'] = train_df.apply(lambda x: bp_dict[x['BodyPart']],axis=1)
valid_df['Bp_label'] = valid_df.apply(lambda x: bp_dict[x['BodyPart']],axis=1)

# %%
valid_df.head()
# Out:
#                                             FilePath  Label BodyPart  Bp_label
# 0  MURA-v1.1/valid/XR_WRIST/patient11185/study1_p...      1    WRIST         1
# 1  MURA-v1.1/valid/XR_WRIST/patient11185/study1_p...      1    WRIST         1
# 2  MURA-v1.1/valid/XR_WRIST/patient11185/study1_p...      1    WRIST         1
# 3  MURA-v1.1/valid/XR_WRIST/patient11185/study1_p...      1    WRIST         1
# 4  MURA-v1.1/valid/XR_WRIST/patient11186/study1_p...      1    WRIST         1

# %%
valid_df.Label.hist()

# %%
train_df.to_csv('train_bp.csv')
valid_df.to_csv('valid_bp.csv')

# %%
import torch
import torchvision
from torchvision import datasets, transforms
import matplotlib.pyplot as plt

mean = [0.5, 0.5, 0.5]
std  = [0.5, 0.5, 0.5]
transform = transforms.Compose([
  transforms.Resize((280, 280)),
  transforms.CenterCrop((224, 224)),
  transforms.ColorJitter(brightness = 2),
  transforms.ToTensor(),
  transforms.Normalize(mean, std),
])

data_test_img = datasets.ImageFolder(root = 'E:\Xing\Data\MURA-v1.1\MURA-v1.1\test',
                                     transform = transform)
data_loader_test_img = torch.utils.data.DataLoader(dataset = data_test_img,
                                                   batch_size = 1,
                                                   shuffle = False)

image, label = next(iter(data_loader_test_img))
img = torchvision.utils.make_grid(image)
img = img.numpy().transpose((1, 2, 0))
img = img * std + mean

plt.imshow(img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-1-bd28d1dc8916> in <module>
#      15
#      16 data_test_img = datasets.ImageFolder(root = 'E:\Xing\Data\MURA-v1.1\MURA-v1.1\test',
# ---> 17                                      transform = transform)
#      18 data_loader_test_img = torch.utils.data.DataLoader(dataset = data_test_img,
#      19                                                    batch_size = 1,
#
# ~\anaconda3\envs\env_torch\lib\site-packages\torchvision\datasets\folder.py in __init__(self, root, transform, target_transform, loader, is_valid_file)
#     207                                           transform=transform,
#     208                                           target_transform=target_transform,
# --> 209                                           is_valid_file=is_valid_file)
#     210         self.imgs = self.samples
#
# ~\anaconda3\envs\env_torch\lib\site-packages\torchvision\datasets\folder.py in __init__(self, root, loader, extensions, transform, target_transform, is_valid_file)
#      91         self.transform = transform
#      92         self.target_transform = target_transform
# ---> 93         classes, class_to_idx = self._find_classes(self.root)
#      94         samples = make_dataset(self.root, class_to_idx, extensions, is_valid_file)
#      95         if len(samples) == 0:
#
# ~\anaconda3\envs\env_torch\lib\site-packages\torchvision\datasets\folder.py in _find_classes(self, dir)
#     120         if sys.version_info >= (3, 5):
#     121             # Faster and available in Python 3.5 and above
# --> 122             classes = [d.name for d in os.scandir(dir) if d.is_dir()]
#     123         else:
#     124             classes = [d for d in os.listdir(dir) if os.path.isdir(os.path.join(dir, d))]
#
# OSError: [WinError 123] The filename, directory name, or volume label syntax is incorrect: 'E:\\Xing\\Data\\MURA-v1.1\\MURA-v1.1\test'

# %%
train_df['Label'] = train_df.apply(lambda x:1 if 'positive' in x.FilePath else 0, axis=1)
train_df['BodyPart'] = train_df.apply(lambda x: x.FilePath.split('/')[2][3:],axis=1)
train_df['StudyType'] = train_df.apply(lambda x: x.FilePath.split('/')[4][:6],axis=1)
valid_df['Label'] = valid_df.apply(lambda x:1 if 'positive' in x.FilePath else 0, axis=1)
valid_df['BodyPart'] = valid_df.apply(lambda x: x.FilePath.split('/')[2][3:],axis=1)
valid_df['StudyType'] = valid_df.apply(lambda x: x.FilePath.split('/')[4][:6],axis=1)

# %%
train_df.head()
# Out:
#                                             FilePath  \
# 0  MURA-v1.1/train/XR_SHOULDER/patient00001/study...
# 1  MURA-v1.1/train/XR_SHOULDER/patient00001/study...
# 2  MURA-v1.1/train/XR_SHOULDER/patient00001/study...
# 3  MURA-v1.1/train/XR_SHOULDER/patient00002/study...
# 4  MURA-v1.1/train/XR_SHOULDER/patient00002/study...
#
#                                          window_path  Label  BodyPart  \
# 0  E:\Xing\MURA\MURA-v1.1\train\XR_SHOULDER\patie...      1  SHOULDER
# 1  E:\Xing\MURA\MURA-v1.1\train\XR_SHOULDER\patie...      1  SHOULDER
# 2  E:\Xing\MURA\MURA-v1.1\train\XR_SHOULDER\patie...      1  SHOULDER
# 3  E:\Xing\MURA\MURA-v1.1\train\XR_SHOULDER\patie...      1  SHOULDER
# 4  E:\Xing\MURA\MURA-v1.1\train\XR_SHOULDER\patie...      1  SHOULDER
#
#   StudyType
# 0    study1
# 1    study1
# 2    study1
# 3    study1
# 4    study1

# %%
valid_df.head()
# Out:
#                                             FilePath  \
# 0  MURA-v1.1/valid/XR_WRIST/patient11185/study1_p...
# 1  MURA-v1.1/valid/XR_WRIST/patient11185/study1_p...
# 2  MURA-v1.1/valid/XR_WRIST/patient11185/study1_p...
# 3  MURA-v1.1/valid/XR_WRIST/patient11185/study1_p...
# 4  MURA-v1.1/valid/XR_WRIST/patient11186/study1_p...
#
#                                          window_path  Label BodyPart StudyType
# 0  E:\Xing\MURA\MURA-v1.1\train\XR_SHOULDER\patie...      1    WRIST    study1
# 1  E:\Xing\MURA\MURA-v1.1\train\XR_SHOULDER\patie...      1    WRIST    study1
# 2  E:\Xing\MURA\MURA-v1.1\train\XR_SHOULDER\patie...      1    WRIST    study1
# 3  E:\Xing\MURA\MURA-v1.1\train\XR_SHOULDER\patie...      1    WRIST    study1
# 4  E:\Xing\MURA\MURA-v1.1\train\XR_SHOULDER\patie...      1    WRIST    study1

# %%
train_df['valid'] = 0
valid_df['valid'] = 1

# %%
main_df = pd.concat([train_df,valid_df])

# %%
main_df.head()
# Out:
#                                             FilePath  \
# 0  MURA-v1.1/train/XR_SHOULDER/patient00001/study...
# 1  MURA-v1.1/train/XR_SHOULDER/patient00001/study...
# 2  MURA-v1.1/train/XR_SHOULDER/patient00001/study...
# 3  MURA-v1.1/train/XR_SHOULDER/patient00002/study...
# 4  MURA-v1.1/train/XR_SHOULDER/patient00002/study...
#
#                                          window_path  Label  BodyPart  \
# 0  E:\Xing\MURA\MURA-v1.1\train\XR_SHOULDER\patie...      1  SHOULDER
# 1  E:\Xing\MURA\MURA-v1.1\train\XR_SHOULDER\patie...      1  SHOULDER
# 2  E:\Xing\MURA\MURA-v1.1\train\XR_SHOULDER\patie...      1  SHOULDER
# 3  E:\Xing\MURA\MURA-v1.1\train\XR_SHOULDER\patie...      1  SHOULDER
# 4  E:\Xing\MURA\MURA-v1.1\train\XR_SHOULDER\patie...      1  SHOULDER
#
#   StudyType  valid
# 0    study1      0
# 1    study1      0
# 2    study1      0
# 3    study1      0
# 4    study1      0

# %%
for label,group in main_df.groupby('valid'):
    group.Label.hist()

# %%
import seaborn as sns

sns.countplot(train_df['Label'])
plt.figure(figsize=(15,7))
sns.countplot(data=train_df,x='BodyPart',hue='Label')
plt.figure(figsize=(15,7))
sns.countplot(data=train_df,x='StudyType',hue='Label')

sns.countplot(valid_df['Label'])
plt.figure(figsize=(15,7))
sns.countplot(data=valid_df,x='BodyPart',hue='Label')
plt.figure(figsize=(15,7))
sns.countplot(data=valid_df,x='StudyType',hue='Label')

# %%
train_df.set_index(["FilePath", "BodyPart"]).count(level="BodyPart")
# Out:
#           window_path  Label  StudyType  valid
# BodyPart
# ELBOW            4931   4931       4931   4931
# FINGER           5106   5106       5106   5106
# FOREARM          1825   1825       1825   1825
# HAND             5543   5543       5543   5543
# HUMERUS          1272   1272       1272   1272
# SHOULDER         8379   8379       8379   8379
# WRIST            9752   9752       9752   9752

# %%
train_df.set_index(["FilePath", "Label"]).count(level="Label")
# Out:
#        window_path  BodyPart  StudyType  valid
# Label
# 0            21935     21935      21935  21935
# 1            14873     14873      14873  14873

# %%
train_df.BodyPart.hist()

# %%
main_df.to_csv('data_valid.csv')

# %%
main_df.head()
# Out:
#                                             FilePath  \
# 0  MURA-v1.1/train/XR_SHOULDER/patient00001/study...
# 1  MURA-v1.1/train/XR_SHOULDER/patient00001/study...
# 2  MURA-v1.1/train/XR_SHOULDER/patient00001/study...
# 3  MURA-v1.1/train/XR_SHOULDER/patient00002/study...
# 4  MURA-v1.1/train/XR_SHOULDER/patient00002/study...
#
#                                          window_path  Label  BodyPart  \
# 0  E:\Xing\MURA\MURA-v1.1\train\XR_SHOULDER\patie...      1  SHOULDER
# 1  E:\Xing\MURA\MURA-v1.1\train\XR_SHOULDER\patie...      1  SHOULDER
# 2  E:\Xing\MURA\MURA-v1.1\train\XR_SHOULDER\patie...      1  SHOULDER
# 3  E:\Xing\MURA\MURA-v1.1\train\XR_SHOULDER\patie...      1  SHOULDER
# 4  E:\Xing\MURA\MURA-v1.1\train\XR_SHOULDER\patie...      1  SHOULDER
#
#   StudyType  valid
# 0    study1      0
# 1    study1      0
# 2    study1      0
# 3    study1      0
# 4    study1      0

# %%
main_df['BodyPart'] == 'SHOULDER'
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27       True
# 28       True
# 29       True
#         ...
# 3167    False
# 3168    False
# 3169    False
# 3170    False
# 3171    False
# 3172    False
# 3173    False
# 3174    False
# 3175    False
# 3176    False
# 3177    False
# 3178    False
# 3179    False
# 3180    False
# 3181    False
# 3182    False
# 3183    False
# 3184    False
# 3185    False
# 3186    False
# 3187    False
# 3188    False
# 3189    False
# 3190    False
# 3191    False
# 3192    False
# 3193    False
# 3194    False
# 3195    False
# 3196    False
# Name: BodyPart, Length: 40005, dtype: bool

# %%
a = np.random.rand(10,10)

# %%
b = np.array([a]*3)

# %%
b.shape
# Out:
# (3, 10, 10)

# %%
b = np.transpose(b,(1,2,0))

# %%
b.shape
# Out:
# (10, 10, 3)

# %%
df = pd.read_excel('1000数据标注cj.xlsx',sheet_name='1000_data')

# %%
df.columns = ['SID','ToT','Abn','Norm','nn','nn','nn']

# %%
df.dropna(subset=['ToT'],inplace=True)
df.head()
# Out:
#       SID  ToT                                        Abn  \
# 2  8105.0  t01  ab00s06e16n01%ab01s18e24n01%ab03s27e41n01
# 3  8106.0  t02                ab00s07e09n01%ab01s25e32n01
# 4  8110.0  t02                              ab00s23e27n02
# 5  8112.0  t01                              ab00s31e35n02
# 6  8113.0  t01                 ab00s0e09n01%ab01s10e35n02
#
#                                        Norm   nn   nn   nn
# 2                              nm00s0e06n02  NaN  NaN  NaN
# 3  nm00s0e07n02%nm01s09e25n02%nm02s32e42n02  NaN  NaN  NaN
# 4                      nm00s0e23%nm01s28e43  NaN  NaN  NaN
# 5                nm00s0e30n02%nm01s35e42n02  NaN  NaN  NaN
# 6                                       NaN  NaN  NaN  NaN

# %%
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#       SID  ToT                                        Abn  \
# 0  8105.0  t01  ab00s06e16n01%ab01s18e24n01%ab03s27e41n01
# 1  8106.0  t02                ab00s07e09n01%ab01s25e32n01
# 2  8110.0  t02                              ab00s23e27n02
# 3  8112.0  t01                              ab00s31e35n02
# 4  8113.0  t01                 ab00s0e09n01%ab01s10e35n02
#
#                                        Norm   nn   nn   nn
# 0                              nm00s0e06n02  NaN  NaN  NaN
# 1  nm00s0e07n02%nm01s09e25n02%nm02s32e42n02  NaN  NaN  NaN
# 2                      nm00s0e23%nm01s28e43  NaN  NaN  NaN
# 3                nm00s0e30n02%nm01s35e42n02  NaN  NaN  NaN
# 4                                       NaN  NaN  NaN  NaN

# %%
# segment different description with '%'
# note that there may be missing some %
key_list=[]
Tot_list=[]
Sig_list = []

for idx,index in tqdm(enumerate(df['SID'])):
    
    n_abn = 0
    n_norm = 0
    if isinstance(df.Abn[idx],str):
        abn_data = df.Abn[idx].split('%')
        n_abn = len(abn_data)
    if isinstance(df.Norm[idx],str):
        norm_data = df.Norm[idx].split('%')
        n_norm = len(norm_data)
    print(index,n_abn,n_norm)
    
    for i in range(n_abn):
        name = str(int(index))+'_a_'+str(i)
        key_list.append(name)
        Sig_list.append(abn_data[i])
        Tot_list.append(df.ToT[idx])
        
    for i in range(n_norm):
        name = str(int(index))+'_n_'+str(i)
        key_list.append(name)
        Sig_list.append(norm_data[i])
        Tot_list.append(df.ToT[idx])
        

data = pd.DataFrame({'index':key_list,
                     'ToT':Tot_list,
                     'Signal':Sig_list
                     })

data.sort_values(by='index',inplace=True)

csv_name = 'main_csv.csv' #main_step1.csv

data.to_csv(csv_name,index = False,sep = ',')

# %%
csv_name = 'main_csv.csv'
data = pd.read_csv(csv_name)

# %%
data.head()
# Out:
#        index  ToT         Signal
# 0  10013_a_0  t02   ab00s0e04n07
# 1  10013_a_1  t02  ab01s08e09n07
# 2  10013_a_2  t02  ab02s18e20n07
# 3  10013_n_0  t02     nm00s20e28
# 4  10017_a_0  t02   ab00s0e05n07

# %%
data['norm'] = data.apply(lambda x: x['index'].split('_')[1], axis=1)

# %%
data['intact']=data.apply(lambda x: 1 if ('s' in x['Signal']) & ('e' in x['Signal']) else 0, axis = 1)

# %%
hist = data.intact.hist()
data.intact.value_counts()
# Out:
# 1    1152
# 0       6
# Name: intact, dtype: int64

# %%
data_c=data[~data['intact'].isin([0])]

# %%
hist = data_c.intact.hist()
data_c.intact.value_counts()
# Out:
# 1    1152
# Name: intact, dtype: int64

# %%
data_c['Start'] = data_c.apply(lambda x:x['Signal'].split('s')[1].split('e')[0],axis=1)
# Out:
# C:\Users\lvxin\Anaconda3\envs\fastai\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_c.head()
# Out:
#        index  ToT         Signal norm  intact Start
# 0  10013_a_0  t02   ab00s0e04n07    a       1     0
# 1  10013_a_1  t02  ab01s08e09n07    a       1    08
# 2  10013_a_2  t02  ab02s18e20n07    a       1    18
# 3  10013_n_0  t02     nm00s20e28    n       1    20
# 4  10017_a_0  t02   ab00s0e05n07    a       1     0

# %%
data_c['End'] = data_c.apply(lambda x:x['Signal'].split('e')[1],axis=1)
# Out:
# C:\Users\lvxin\Anaconda3\envs\fastai\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_c['End'] = data_c.apply(lambda x: x['End'].split('n')[0] if 'n' in x['End'] else x['End'], axis=1)
# Out:
# C:\Users\lvxin\Anaconda3\envs\fastai\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_c.head()
# Out:
#        index  ToT         Signal norm  intact Start End
# 0  10013_a_0  t02   ab00s0e04n07    a       1     0  04
# 1  10013_a_1  t02  ab01s08e09n07    a       1    08  09
# 2  10013_a_2  t02  ab02s18e20n07    a       1    18  20
# 3  10013_n_0  t02     nm00s20e28    n       1    20  28
# 4  10017_a_0  t02   ab00s0e05n07    a       1     0  05

# %%
data_c['Length'] = data_c.apply(lambda x: int(x['End'])-int(x['Start']), axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-e450f4067e66> in <module>
# ----> 1 data_c['Length'] = data_c.apply(lambda x: int(x['End'])-int(x['Start']), axis=1)
#
# ~\Anaconda3\envs\fastai\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    6876             kwds=kwds,
#    6877         )
# -> 6878         return op.get_result()
#    6879
#    6880     def applymap(self, func) -> "DataFrame":
#
# ~\Anaconda3\envs\fastai\lib\site-packages\pandas\core\apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# ~\Anaconda3\envs\fastai\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     294             try:
#     295                 result = libreduction.compute_reduction(
# --> 296                     values, self.f, axis=self.axis, dummy=dummy, labels=labels
#     297                 )
#     298             except ValueError as err:
#
# pandas\_libs\reduction.pyx in pandas._libs.reduction.compute_reduction()
#
# pandas\_libs\reduction.pyx in pandas._libs.reduction.Reducer.get_result()
#
# <ipython-input-40-e450f4067e66> in <lambda>(x)
# ----> 1 data_c['Length'] = data_c.apply(lambda x: int(x['End'])-int(x['Start']), axis=1)
#
# ValueError: invalid literal for int() with base 10: '42s'

# %%
data_c[data_c['End']=='42s']
#data_c[data_c.Length.isin([-494])]
# Out:
#          index  ToT          Signal norm  intact Start  End
# 205  10947_a_1  t02  ab01s38e42sn03    a       1    38  42s

# %%
data_c.loc[205,'End']
# Out:
# '42s'

# %%
data_c.loc[205,'End']=42
# Out:
# C:\Users\lvxin\Anaconda3\envs\fastai\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
data_c.loc[205,'End']
# Out:
# 42

# %%
data_c['Length'] = data_c.apply(lambda x: int(x['End'])-int(x['Start']), axis=1)
# Out:
# C:\Users\lvxin\Anaconda3\envs\fastai\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_c.head()
# Out:
#        index  ToT         Signal norm  intact Start End  Length
# 0  10013_a_0  t02   ab00s0e04n07    a       1     0  04       4
# 1  10013_a_1  t02  ab01s08e09n07    a       1    08  09       1
# 2  10013_a_2  t02  ab02s18e20n07    a       1    18  20       2
# 3  10013_n_0  t02     nm00s20e28    n       1    20  28       8
# 4  10017_a_0  t02   ab00s0e05n07    a       1     0  05       5

# %%
data_c.rename(columns={'index':'key'}, inplace=True)
# Out:
# C:\Users\lvxin\Anaconda3\envs\fastai\lib\site-packages\pandas\core\frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
data_c.head()
# Out:
#          key  ToT         Signal norm  intact Start End
# 0  10013_a_0  t02   ab00s0e04n07    a       1     0  04
# 1  10013_a_1  t02  ab01s08e09n07    a       1    08  09
# 2  10013_a_2  t02  ab02s18e20n07    a       1    18  20
# 3  10013_n_0  t02     nm00s20e28    n       1    20  28
# 4  10017_a_0  t02   ab00s0e05n07    a       1     0  05

# %%
data_c.Length.hist()

# %%
data_c.Length.value_counts()
# Out:
#  4      75
#  42     65
#  5      57
#  6      57
#  2      45
#         ..
#  144     1
#  147     1
#  69      1
#  156     1
# -494     1
# Name: Length, Length: 140, dtype: int64

# %%
data_c[data_c.Length.isin([-50])]
# Out:
#         index  ToT        Signal norm  intact Start End  Length
# 933  9520_a_0  t01  ab00s0e04n01    a       1    54  04     -50

# %%
data_c.loc[933,'Start']=0
# Out:
# C:\Users\lvxin\Anaconda3\envs\fastai\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
data_c['Length'] = data_c.apply(lambda x: int(x['End'])-int(x['Start']), axis=1)
# Out:
# C:\Users\lvxin\Anaconda3\envs\fastai\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_c.Length.value_counts()
# Out:
# 4      75
# 42     65
# 6      58
# 5      57
# 7      45
#        ..
# 144     1
# 147     1
# 65      1
# 156     1
# 298     1
# Name: Length, Length: 139, dtype: int64

# %%
data_c.Length.hist()

# %%
data_c['norm'] = data_c.apply(lambda x: 1 if x['norm']=='n' else 0, axis=1)
# Out:
# C:\Users\lvxin\Anaconda3\envs\fastai\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_c.norm.hist()

# %%
data_c[data_c.norm.isin([1])].Length.sum()
data_c[data_c.norm.isin([0])].Length.sum()
pd.Series([36052,14219]).plot.bar()

# %%
data_c.head()
# Out:
#        index  ToT         Signal  norm  intact Start End  Length
# 0  10013_a_0  t02   ab00s0e04n07     0       1     0  04       4
# 1  10013_a_1  t02  ab01s08e09n07     0       1    08  09       1
# 2  10013_a_2  t02  ab02s18e20n07     0       1    18  20       2
# 3  10013_n_0  t02     nm00s20e28     1       1    20  28       8
# 4  10017_a_0  t02   ab00s0e05n07     0       1     0  05       5

# %%
data_c['key']=data_c.apply(lambda x: int(x['index'].split('_')[0]),axis=1)

# %%
data_c.head()
# Out:
#        index  ToT         Signal  norm  intact Start End  Length    key
# 0  10013_a_0  t02   ab00s0e04n07     0       1     0  04       4  10013
# 1  10013_a_1  t02  ab01s08e09n07     0       1    08  09       1  10013
# 2  10013_a_2  t02  ab02s18e20n07     0       1    18  20       2  10013
# 3  10013_n_0  t02     nm00s20e28     1       1    20  28       8  10013
# 4  10017_a_0  t02   ab00s0e05n07     0       1     0  05       5  10017

# %%
data_c=data_c.sort_values(by='key',ascending=True)
data_c=data_c.reset_index(drop=True)
data_c.head()
# Out:
#       index  ToT         Signal  norm  intact Start End  Length   key
# 0  8105_a_1  t01  ab01s18e24n01     0       1    18  24       6  8105
# 1  8105_a_0  t01  ab00s06e16n01     0       1    06  16      10  8105
# 2  8105_a_2  t01  ab03s27e41n01     0       1    27  41      14  8105
# 3  8105_n_0  t01   nm00s0e06n02     1       1     0  06       6  8105
# 4  8106_n_1  t02  nm01s09e25n02     1       1    09  25      16  8106

# %%
data_c.to_csv('main_step2.csv')

# %% [markdown]
# # generating the data

# %%
#data_c=pd.read_csv('main_step2.csv')

# %%
key_set = set(data_c.key)

# %%
len(key_set)
# Out:
# 603

# %%
data_c.key.value_counts()
# Out:
# 11595    12
# 9914     10
# 11394     8
# 11449     8
# 11006     8
#          ..
# 11230     1
# 11231     1
# 11232     1
# 11233     1
# 10465     1
# Name: key, Length: 603, dtype: int64

# %%
path = r'E:\Data\Medlink\QualityControl\600\data'
data_files = glob2.glob(os.path.join(path,'*csv'))

# %%
key_fn = lambda x: x.split(os.sep)[-1].split('.')[0]

# %%
file_list = []
for file in data_files:
    file_list.append(key_fn(file))
file_set = set(file_list)
print(len(file_set))
file_set
# Out:
# 598
# {'10013',
#  '10017',
#  '10018',
#  '10019',
#  '10076',
#  '10083',
#  '10087',
#  '10089',
#  '10092',
#  '10094',
#  '10095',
#  '10099',
#  '10101',
#  '10104',
#  '10106',
#  '10109',
#  '10110',
#  '10112',
#  '10117',
#  '10121',
#  '10122',
#  '10123',
#  '10125',
#  '10128',
#  '10226',
#  '10227',
#  '10228',
#  '10240',
#  '10241',
#  '10242',
#  '10255',
#  '10271',
#  '10274',
#  '10277',
#  '10279',
#  '10281',
#  '10300',
#  '10301',
#  '10302',
#  '10303',
#  '10304',
#  '10305',
#  '10306',
#  '10316',
#  '10319',
#  '10321',
#  '10322',
#  '10323',
#  '10324',
#  '10326',
#  '10328',
#  '10345',
#  '10393',
#  '10394',
#  '10395',
#  '10396',
#  '10397',
#  '10406',
#  '10407',
#  '10408',
#  '10414',
#  '10415',
#  '10416',
#  '10419',
#  '10458',
#  '10459',
#  '10460',
#  '10461',
#  '10463',
#  '10464',
#  '10518',
#  '10519',
#  '10520',
#  '10546',
#  '10596',
#  '10608',
#  '10609',
#  '10825',
#  '10826',
#  '10827',
#  '10829',
#  '10833',
#  '10834',
#  '10835',
#  '10836',
#  '10837',
#  '10838',
#  '10839',
#  '10840',
#  '10842',
#  '10843',
#  '10844',
#  '10845',
#  '10846',
#  '10847',
#  '10848',
#  '10850',
#  '10851',
#  '10852',
#  '10853',
#  '10854',
#  '10856',
#  '10857',
#  '10858',
#  '10859',
#  '10860',
#  '10861',
#  '10863',
#  '10864',
#  '10890',
#  '10891',
#  '10892',
#  '10893',
#  '10894',
#  '10895',
#  '10896',
#  '10944',
#  '10945',
#  '10946',
#  '10947',
#  '10949',
#  '10951',
#  '10952',
#  '10953',
#  '10954',
#  '10955',
#  '10956',
#  '10957',
#  '10958',
#  '10960',
#  '10967',
#  '10968',
#  '10969',
#  '10970',
#  '10971',
#  '10972',
#  '10973',
#  '10974',
#  '10975',
#  '10976',
#  '10977',
#  '10986',
#  '10987',
#  '10988',
#  '10989',
#  '10990',
#  '10991',
#  '10992',
#  '10993',
#  '10994',
#  '10995',
#  '10996',
#  '10997',
#  '10998',
#  '10999',
#  '11000',
#  '11002',
#  '11003',
#  '11004',
#  '11005',
#  '11006',
#  '11007',
#  '11008',
#  '11009',
#  '11010',
#  '11011',
#  '11020',
#  '11021',
#  '11022',
#  '11023',
#  '11024',
#  '11025',
#  '11026',
#  '11027',
#  '11028',
#  '11029',
#  '11030',
#  '11058',
#  '11069',
#  '11107',
#  '11153',
#  '11158',
#  '11159',
#  '11160',
#  '11161',
#  '11162',
#  '11163',
#  '11164',
#  '11165',
#  '11166',
#  '11167',
#  '11168',
#  '11169',
#  '11170',
#  '11171',
#  '11172',
#  '11173',
#  '11175',
#  '11176',
#  '11178',
#  '11179',
#  '11181',
#  '11186',
#  '11196',
#  '11197',
#  '11198',
#  '11200',
#  '11201',
#  '11202',
#  '11203',
#  '11204',
#  '11205',
#  '11206',
#  '11207',
#  '11208',
#  '11209',
#  '11211',
#  '11212',
#  '11213',
#  '11214',
#  '11215',
#  '11216',
#  '11218',
#  '11219',
#  '11220',
#  '11221',
#  '11222',
#  '11223',
#  '11224',
#  '11225',
#  '11226',
#  '11227',
#  '11229',
#  '11230',
#  '11231',
#  '11232',
#  '11233',
#  '11236',
#  '11237',
#  '11238',
#  '11239',
#  '11240',
#  '11241',
#  '11242',
#  '11243',
#  '11244',
#  '11245',
#  '11246',
#  '11374',
#  '11379',
#  '11380',
#  '11393',
#  '11394',
#  '11395',
#  '11396',
#  '11397',
#  '11398',
#  '11399',
#  '11400',
#  '11401',
#  '11407',
#  '11408',
#  '11409',
#  '11410',
#  '11414',
#  '11415',
#  '11417',
#  '11418',
#  '11419',
#  '11420',
#  '11421',
#  '11422',
#  '11423',
#  '11424',
#  '11426',
#  '11427',
#  '11428',
#  '11429',
#  '11430',
#  '11431',
#  '11432',
#  '11435',
#  '11436',
#  '11437',
#  '11439',
#  '11440',
#  '11443',
#  '11444',
#  '11445',
#  '11446',
#  '11448',
#  '11449',
#  '11450',
#  '11451',
#  '11454',
#  '11455',
#  '11456',
#  '11457',
#  '11458',
#  '11460',
#  '11461',
#  '11462',
#  '11463',
#  '11464',
#  '11465',
#  '11466',
#  '11468',
#  '11469',
#  '11470',
#  '11471',
#  '11475',
#  '11476',
#  '11477',
#  '11478',
#  '11481',
#  '11482',
#  '11483',
#  '11484',
#  '11486',
#  '11487',
#  '11488',
#  '11492',
#  '11500',
#  '11503',
#  '11504',
#  '11505',
#  '11506',
#  '11507',
#  '11508',
#  '11527',
#  '11528',
#  '11543',
#  '11544',
#  '11547',
#  '11548',
#  '11551',
#  '11552',
#  '11553',
#  '11554',
#  '11555',
#  '11563',
#  '11567',
#  '11568',
#  '11569',
#  '11570',
#  '11571',
#  '11572',
#  '11573',
#  '11574',
#  '11575',
#  '11576',
#  '11577',
#  '11578',
#  '11579',
#  '11580',
#  '11581',
#  '11582',
#  '11583',
#  '11584',
#  '11585',
#  '11586',
#  '11587',
#  '11588',
#  '11589',
#  '11590',
#  '11591',
#  '11593',
#  '11594',
#  '11595',
#  '8105',
#  '8106',
#  '8108',
#  '8109',
#  '8110',
#  '8112',
#  '8113',
#  '8118',
#  '8119',
#  '8120',
#  '8150',
#  '8363',
#  '8364',
#  '8365',
#  '8370',
#  '8371',
#  '8389',
#  '8390',
#  '8391',
#  '8392',
#  '8393',
#  '8399',
#  '8400',
#  '8401',
#  '8417',
#  '8418',
#  '8432',
#  '8433',
#  '8452',
#  '8453',
#  '8454',
#  '8455',
#  '8458',
#  '8464',
#  '8491',
#  '8494',
#  '8499',
#  '8508',
#  '8509',
#  '8514',
#  '8517',
#  '8521',
#  '8522',
#  '8523',
#  '8525',
#  '8527',
#  '8528',
#  '8538',
#  '8539',
#  '8540',
#  '8541',
#  '8542',
#  '8543',
#  '8544',
#  '8545',
#  '8546',
#  '8548',
#  '8549',
#  '8550',
#  '8551',
#  '8552',
#  '8553',
#  '8554',
#  '8555',
#  '8556',
#  '8557',
#  '8558',
#  '8559',
#  '8560',
#  '8561',
#  '8562',
#  '8563',
#  '8564',
#  '8565',
#  '8570',
#  '8742',
#  '9036',
#  '9303',
#  '9306',
#  '9312',
#  '9313',
#  '9315',
#  '9316',
#  '9317',
#  '9320',
#  '9348',
#  '9349',
#  '9350',
#  '9351',
#  '9413',
#  '9414',
#  '9415',
#  '9418',
#  '9419',
#  '9420',
#  '9421',
#  '9422',
#  '9423',
#  '9424',
#  '9425',
#  '9426',
#  '9471',
#  '9472',
#  '9473',
#  '9474',
#  '9481',
#  '9482',
#  '9506',
#  '9516',
#  '9517',
#  '9518',
#  '9519',
#  '9520',
#  '9522',
#  '9523',
#  '9524',
#  '9525',
#  '9526',
#  '9539',
#  '9542',
#  '9543',
#  '9544',
#  '9545',
#  '9546',
#  '9549',
#  '9553',
#  '9554',
#  '9555',
#  '9558',
#  '9559',
#  '9561',
#  '9564',
#  '9566',
#  '9572',
#  '9573',
#  '9574',
#  '9575',
#  '9578',
#  '9579',
#  '9580',
#  '9587',
#  '9589',
#  '9590',
#  '9591',
#  '9592',
#  '9602',
#  '9624',
#  '9627',
#  '9628',
#  '9629',
#  '9630',
#  '9642',
#  '9666',
#  '9667',
#  '9668',
#  '9671',
#  '9672',
#  '9673',
#  '9674',
#  '9675',
#  '9678',
#  '9679',
#  '9681',
#  '9685',
#  '9686',
#  '9687',
#  '9695',
#  '9696',
#  '9714',
#  '9715',
#  '9717',
#  '9718',
#  '9719',
#  '9723',
#  '9738',
#  '9751',
#  '9752',
#  '9753',
#  '9754',
#  '9755',
#  '9757',
#  '9759',
#  '9760',
#  '9798',
#  '9799',
#  '9801',
#  '9802',
#  '9803',
#  '9816',
#  '9817',
#  '9818',
#  '9819',
#  '9826',
#  '9835',
#  '9844',
#  '9853',
#  '9866',
#  '9868',
#  '9869',
#  '9871',
#  '9872',
#  '9874',
#  '9878',
#  '9879',
#  '9880',
#  '9881',
#  '9882',
#  '9883',
#  '9884',
#  '9887',
#  '9888',
#  '9914',
#  '9915',
#  '9916',
#  '9917',
#  '9918',
#  '9919',
#  '9920',
#  '9921',
#  '9922',
#  '9923',
#  '9926',
#  '9927',
#  '9975',
#  '9977',
#  '9978',
#  '9980',
#  '9981',
#  '9982'}

# %%
print(len(key_set),len(file_set))
print(len(key_set-file_set))
key_set-file_set
# Out:
# 603 598
# 603
# {8105,
#  8106,
#  8108,
#  8109,
#  8110,
#  8112,
#  8113,
#  8150,
#  8363,
#  8364,
#  8365,
#  8370,
#  8371,
#  8389,
#  8390,
#  8391,
#  8392,
#  8393,
#  8399,
#  8400,
#  8401,
#  8417,
#  8418,
#  8432,
#  8433,
#  8452,
#  8453,
#  8454,
#  8455,
#  8458,
#  8461,
#  8464,
#  8494,
#  8499,
#  8508,
#  8509,
#  8514,
#  8517,
#  8521,
#  8522,
#  8523,
#  8525,
#  8527,
#  8528,
#  8538,
#  8539,
#  8540,
#  8541,
#  8542,
#  8543,
#  8544,
#  8545,
#  8546,
#  8548,
#  8549,
#  8550,
#  8551,
#  8552,
#  8553,
#  8554,
#  8555,
#  8556,
#  8557,
#  8558,
#  8559,
#  8560,
#  8561,
#  8562,
#  8563,
#  8564,
#  8565,
#  8570,
#  8742,
#  9036,
#  9303,
#  9306,
#  9312,
#  9313,
#  9315,
#  9316,
#  9317,
#  9320,
#  9348,
#  9349,
#  9350,
#  9351,
#  9413,
#  9414,
#  9415,
#  9418,
#  9419,
#  9420,
#  9421,
#  9422,
#  9423,
#  9424,
#  9425,
#  9426,
#  9471,
#  9472,
#  9473,
#  9474,
#  9481,
#  9482,
#  9506,
#  9516,
#  9517,
#  9518,
#  9519,
#  9520,
#  9522,
#  9523,
#  9524,
#  9525,
#  9526,
#  9539,
#  9542,
#  9543,
#  9544,
#  9545,
#  9546,
#  9549,
#  9553,
#  9554,
#  9555,
#  9558,
#  9559,
#  9561,
#  9564,
#  9566,
#  9572,
#  9573,
#  9574,
#  9575,
#  9577,
#  9578,
#  9579,
#  9580,
#  9587,
#  9589,
#  9590,
#  9591,
#  9592,
#  9602,
#  9624,
#  9627,
#  9628,
#  9629,
#  9630,
#  9642,
#  9666,
#  9667,
#  9668,
#  9671,
#  9672,
#  9673,
#  9674,
#  9675,
#  9678,
#  9679,
#  9681,
#  9685,
#  9686,
#  9687,
#  9695,
#  9696,
#  9714,
#  9715,
#  9717,
#  9718,
#  9719,
#  9723,
#  9738,
#  9751,
#  9752,
#  9753,
#  9754,
#  9755,
#  9757,
#  9759,
#  9760,
#  9798,
#  9799,
#  9801,
#  9802,
#  9803,
#  9816,
#  9817,
#  9818,
#  9819,
#  9826,
#  9835,
#  9844,
#  9853,
#  9866,
#  9868,
#  9869,
#  9871,
#  9872,
#  9874,
#  9878,
#  9879,
#  9880,
#  9881,
#  9882,
#  9883,
#  9884,
#  9887,
#  9888,
#  9914,
#  9915,
#  9916,
#  9917,
#  9918,
#  9919,
#  9920,
#  9921,
#  9922,
#  9923,
#  9926,
#  9927,
#  9975,
#  9977,
#  9978,
#  9980,
#  9981,
#  9982,
#  10013,
#  10017,
#  10018,
#  10019,
#  10076,
#  10080,
#  10083,
#  10087,
#  10089,
#  10092,
#  10094,
#  10095,
#  10097,
#  10099,
#  10101,
#  10104,
#  10106,
#  10109,
#  10110,
#  10112,
#  10117,
#  10121,
#  10122,
#  10123,
#  10124,
#  10125,
#  10128,
#  10225,
#  10226,
#  10227,
#  10228,
#  10240,
#  10241,
#  10242,
#  10255,
#  10271,
#  10273,
#  10274,
#  10277,
#  10279,
#  10281,
#  10300,
#  10301,
#  10302,
#  10303,
#  10304,
#  10305,
#  10306,
#  10316,
#  10319,
#  10321,
#  10322,
#  10323,
#  10324,
#  10326,
#  10328,
#  10345,
#  10393,
#  10394,
#  10395,
#  10396,
#  10397,
#  10406,
#  10407,
#  10408,
#  10414,
#  10415,
#  10416,
#  10419,
#  10458,
#  10459,
#  10460,
#  10461,
#  10463,
#  10464,
#  10465,
#  10518,
#  10519,
#  10520,
#  10546,
#  10596,
#  10608,
#  10609,
#  10825,
#  10826,
#  10827,
#  10829,
#  10833,
#  10834,
#  10835,
#  10836,
#  10837,
#  10838,
#  10839,
#  10840,
#  10842,
#  10843,
#  10844,
#  10845,
#  10846,
#  10847,
#  10848,
#  10850,
#  10851,
#  10852,
#  10853,
#  10854,
#  10856,
#  10857,
#  10858,
#  10859,
#  10860,
#  10861,
#  10863,
#  10864,
#  10890,
#  10891,
#  10892,
#  10893,
#  10894,
#  10895,
#  10896,
#  10944,
#  10945,
#  10946,
#  10947,
#  10949,
#  10951,
#  10952,
#  10953,
#  10954,
#  10955,
#  10956,
#  10957,
#  10958,
#  10960,
#  10967,
#  10968,
#  10969,
#  10970,
#  10971,
#  10972,
#  10973,
#  10974,
#  10975,
#  10976,
#  10977,
#  10986,
#  10987,
#  10988,
#  10989,
#  10990,
#  10991,
#  10992,
#  10993,
#  10994,
#  10995,
#  10996,
#  10997,
#  10998,
#  10999,
#  11000,
#  11002,
#  11003,
#  11004,
#  11005,
#  11006,
#  11007,
#  11008,
#  11009,
#  11010,
#  11011,
#  11020,
#  11021,
#  11022,
#  11023,
#  11024,
#  11025,
#  11026,
#  11027,
#  11028,
#  11029,
#  11030,
#  11058,
#  11068,
#  11069,
#  11107,
#  11153,
#  11158,
#  11159,
#  11160,
#  11161,
#  11162,
#  11163,
#  11164,
#  11165,
#  11166,
#  11167,
#  11168,
#  11169,
#  11170,
#  11171,
#  11172,
#  11173,
#  11175,
#  11176,
#  11178,
#  11179,
#  11181,
#  11186,
#  11196,
#  11197,
#  11198,
#  11200,
#  11201,
#  11202,
#  11203,
#  11204,
#  11205,
#  11206,
#  11207,
#  11208,
#  11209,
#  11211,
#  11212,
#  11213,
#  11214,
#  11215,
#  11216,
#  11218,
#  11219,
#  11220,
#  11221,
#  11222,
#  11223,
#  11224,
#  11225,
#  11226,
#  11227,
#  11229,
#  11230,
#  11231,
#  11232,
#  11233,
#  11236,
#  11237,
#  11238,
#  11239,
#  11240,
#  11241,
#  11242,
#  11243,
#  11244,
#  11245,
#  11246,
#  11374,
#  11379,
#  11380,
#  11393,
#  11394,
#  11395,
#  11396,
#  11397,
#  11398,
#  11399,
#  11400,
#  11401,
#  11407,
#  11408,
#  11409,
#  11410,
#  11414,
#  11415,
#  11417,
#  11418,
#  11419,
#  11420,
#  11421,
#  11422,
#  11423,
#  11424,
#  11426,
#  11427,
#  11428,
#  11429,
#  11430,
#  11431,
#  11432,
#  11435,
#  11436,
#  11437,
#  11439,
#  11440,
#  11443,
#  11444,
#  11445,
#  11446,
#  11448,
#  11449,
#  11450,
#  11451,
#  11454,
#  11455,
#  11456,
#  11457,
#  11458,
#  11460,
#  11461,
#  11462,
#  11463,
#  11465,
#  11466,
#  11467,
#  11468,
#  11469,
#  11470,
#  11471,
#  11475,
#  11476,
#  11477,
#  11478,
#  11481,
#  11482,
#  11483,
#  11484,
#  11486,
#  11487,
#  11488,
#  11492,
#  11500,
#  11503,
#  11504,
#  11505,
#  11506,
#  11507,
#  11508,
#  11527,
#  11528,
#  11543,
#  11544,
#  11547,
#  11548,
#  11551,
#  11552,
#  11553,
#  11554,
#  11555,
#  11563,
#  11567,
#  11568,
#  11569,
#  11570,
#  11571,
#  11572,
#  11573,
#  11574,
#  11575,
#  11576,
#  11577,
#  11578,
#  11579,
#  11580,
#  11581,
#  11582,
#  11583,
#  11584,
#  11585,
#  11586,
#  11587,
#  11588,
#  11589,
#  11590,
#  11591,
#  11593,
#  11594,
#  11595}

# %%
ID_set = set(data_c.key.apply(lambda x: str(x)))

# %%
print(len(ID_set),len(file_set))
print(len(ID_set-file_set))
diff_set = ID_set-file_set
same_set = ID_set&file_set
# Out:
# 603 598
# 10

# %%
len(same_set)
# Out:
# 593

# %%
diff_set
# Out:
# {'10080',
#  '10097',
#  '10124',
#  '10225',
#  '10273',
#  '10465',
#  '11068',
#  '11467',
#  '8461',
#  '9577'}

# %%
print(diff_set&same_set)
# Out:
# set()

# %%
diff_set<ID_set
# Out:
# True

# %%
diff_set<file_set
# Out:
# False

# %% [markdown]
# ## ----------------------------------

# %%
file_name=[]
file_path=[]
for file in data_files:
    file_name.append(int(key_fn(file)))
    file_path.append(file)

file_df = pd.DataFrame({
    'SID':file_name,
    'Path':file_path
})

# %%
file_df=file_df.sort_values(by='SID',ascending=True)
file_df=file_df.reset_index(drop=True)
file_df.head()
# Out:
#     SID                                              Path
# 0  8105  E:\Data\Medlink\QualityControl\600\data\8105.csv
# 1  8106  E:\Data\Medlink\QualityControl\600\data\8106.csv
# 2  8108  E:\Data\Medlink\QualityControl\600\data\8108.csv
# 3  8109  E:\Data\Medlink\QualityControl\600\data\8109.csv
# 4  8110  E:\Data\Medlink\QualityControl\600\data\8110.csv

# %%
file_df.to_csv('data_file.csv')

# %% [markdown]
# ## -----------------------------------

# %%
file_dict = {}
file_df = pd.read_csv('data_file.csv')
for idx,sid in enumerate(file_df.SID):
    temp = {str(sid):file_df['Path'][idx]}
#     print(str(file_df.Path[idx]))
    file_dict.update(temp)
len(file_dict)
# Out:
# 598

# %%
main_df1 = pd.read_csv('main_step2.csv')

# %%
main_df1.head()
# Out:
#    Unnamed: 0     index  ToT         Signal  norm  intact  Start  End  Length  \
# 0           0  8105_a_1  t01  ab01s18e24n01     0       1     18   24       6
# 1           1  8105_a_0  t01  ab00s06e16n01     0       1      6   16      10
# 2           2  8105_a_2  t01  ab03s27e41n01     0       1     27   41      14
# 3           3  8105_n_0  t01   nm00s0e06n02     1       1      0    6       6
# 4           4  8106_n_1  t02  nm01s09e25n02     1       1      9   25      16
#
#     key
# 0  8105
# 1  8105
# 2  8105
# 3  8105
# 4  8106

# %%
main_df1.rename(columns={'key':'main_key'},inplace=True)
main_df1.rename(columns={'index':'key'},inplace=True)

# %%
main_df1.head()
# Out:
#    Unnamed: 0       key  ToT         Signal  norm  intact  Start  End  Length  \
# 0           0  8105_a_1  t01  ab01s18e24n01     0       1     18   24       6
# 1           1  8105_a_0  t01  ab00s06e16n01     0       1      6   16      10
# 2           2  8105_a_2  t01  ab03s27e41n01     0       1     27   41      14
# 3           3  8105_n_0  t01   nm00s0e06n02     1       1      0    6       6
# 4           4  8106_n_1  t02  nm01s09e25n02     1       1      9   25      16
#
#    main_key
# 0      8105
# 1      8105
# 2      8105
# 3      8105
# 4      8106

# %% [markdown]
# ## seg data generation

# %%
path_list=[]
key_list=[]
key_s_list=[]
start_list=[]
end_list=[]
signal_list=[]
total_length=[]
segname_list=[]
maxlen_list=[]

len_patch = 4 #second
fs = 250*4
base_dir = r'E:\Data\Medlink\QualityControl\600\seg_data'

key_fn = lambda x: x.split('_')[0]

for idx,key in enumerate(tqdm(main_df1['key'])):
    data_len = main_df1.Length[idx]
    n = (data_len)//len_patch
    
    key_t = main_df1.key[idx]
    key = key_fn(main_df1.key[idx])
    
    start = main_df1.Start[idx]
    
    if 'n' in key_t:
        data_len = n
    elif 'a' in key_t:
        data_len = n+1

    try:
#         print(idx,key_t,data_len,main_df1.Signal[idx],file_dict[key])
        signal = pd.read_csv(file_dict[key])
        signal.columns = ['data']
        max_len = len(signal)
#         print(key, file_dict[key])
#         print(signal)
    except:
        print(key,' file not found.')
        continue
    
#     print(idx,key,key_t,n)

#     if idx >=100:
#         break
    
    
            
    
    for i in range(data_len):
        key_tmp = key_t+'_'+str(i)
        start_tmp = start + i*len_patch
        sta_p = start_tmp*fs
        end_p = sta_p+len_patch*fs
        
        if (end_p/4+1)>max_len:
            print('warning:',key_tmp,max_len,end_p)
            continue
        
#         sig_tmp = signal.data[sta_p:end_p]
        
        sig_seg_tmp = signal.data.loc[sta_p:end_p]
        seg_csv_name = os.path.join(base_dir,key_tmp+'.csv')
        
#         print(key_tmp,n,i,start,sta_p,end_p,seg_csv_name)
        
        sig_seg_tmp.to_csv(seg_csv_name)
        
        segname_list.append(seg_csv_name)
        
        key_s_list.append(key_tmp)
        key_list.append(int(key))
        path_list.append(file_dict[key])
        start_list.append(sta_p)
        end_list.append(end_p)
        signal_list.append(main_df1.Signal[idx])
        maxlen_list.append(max_len)

# %%
sig_seg_df = pd.DataFrame({
    'key':key_list,
    'key_seg':key_s_list,
    'signal':signal_list,
    'path':path_list,
    'start':start_list,
    'end':end_list,
    'seg_path':segname_list,
    'max_len':maxlen_list
})

# %%
sig_seg_df['max_len'] = sig_seg_df.apply(lambda x: (x['max_len']-1)*4,axis=1)

# %%
sig_seg_df['tag']=sig_seg_df.apply(lambda x: 1 if x['key_seg'].split('_')[1]=='a' else 0,axis=1)

# %%
sig_seg_df.tag.hist()

# %%
sig_seg_df.to_csv('sig_seg.csv')

# %% [markdown]
# ## prepare for the classification

# %%
base_dir =  r'E:\Data\Medlink\QualityControl\600'
csv = 'sig_seg.csv'
df = pd.read_csv(os.path.join(base_dir,csv))
df.head()
# Out:
#    Unnamed: 0   key     key_seg         signal  \
# 0           0  8105  8105_a_1_0  ab01s18e24n01
# 1           1  8105  8105_a_1_1  ab01s18e24n01
# 2           2  8105  8105_a_0_0  ab00s06e16n01
# 3           3  8105  8105_a_0_1  ab00s06e16n01
# 4           4  8105  8105_a_0_2  ab00s06e16n01
#
#                                                path  start    end  \
# 0  E:\Data\Medlink\QualityControl\600\data\8105.csv  18000  22000
# 1  E:\Data\Medlink\QualityControl\600\data\8105.csv  22000  26000
# 2  E:\Data\Medlink\QualityControl\600\data\8105.csv   6000  10000
# 3  E:\Data\Medlink\QualityControl\600\data\8105.csv  10000  14000
# 4  E:\Data\Medlink\QualityControl\600\data\8105.csv  14000  18000
#
#                                             seg_path  max_len  tag
# 0  E:\Data\Medlink\QualityControl\600\seg_data\81...    43000    1
# 1  E:\Data\Medlink\QualityControl\600\seg_data\81...    43000    1
# 2  E:\Data\Medlink\QualityControl\600\seg_data\81...    43000    1
# 3  E:\Data\Medlink\QualityControl\600\seg_data\81...    43000    1
# 4  E:\Data\Medlink\QualityControl\600\seg_data\81...    43000    1

# %%
key_set = set(df.key)
len(key_set)
SEED = 1
patients_verified = list(set(key_set))
N_SELECT_total = len(set(key_set))
N_SELECT_valid = round(N_SELECT_total*0.2)
np.random.seed(SEED)

# %%
# split for train/valid
patients_selected = np.random.choice(patients_verified, N_SELECT_valid, replace=False)
patients_train = list(set(patients_verified) - set(patients_selected))
print('verified patients: {}'.format(len(patients_verified)))
print('selected patients: {}'.format(len(patients_selected)))
print('selected patients for train: {}'.format(len(patients_train)))
# Out:
# verified patients: 592
# selected patients: 118
# selected patients for train: 474

# %%
df['valid']=df.apply(lambda x: 1 if x['key'] in set(patients_selected) else 0, axis=1)

# %%
grouped = df.groupby(df['valid'])
for value, group in grouped:
    plt.figure()
    group.tag.hist()

# %%
df.valid.hist()

# %%
df.to_csv('ecg_classification.csv')
